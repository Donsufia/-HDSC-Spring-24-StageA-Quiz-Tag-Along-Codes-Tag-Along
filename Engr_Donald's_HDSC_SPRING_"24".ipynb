# %% [markdown]
# <a href="https://colab.research.google.com/github/Donsufia/-HDSC-Spring-24-StageA-Quiz-Tag-Along-Codes-Tag-Along/blob/main/Engr_Donald's_HDSC_SPRING_%2224%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Engr Donald Udofia HDSC Spring '24' Stage A Quiz**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding ="latin-1")

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.groupby("Item").sum()
# Out:
#                      Area Code  \
# Item
# Alcohol, Non-Food        38447
# Alcoholic Beverages      75016
# Animal Products          18060
# Animal fats              85279
# Apples and products      69280
# ...                        ...
# Vegetables, Other        77779
# Vegetal Products         18060
# Wheat and products       87073
# Wine                     66206
# Yams                     50798
#
#                                                                   Area  \
# Item
# Alcohol, Non-Food    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAngo...
# Alcoholic Beverages  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Animal Products      AlgeriaAlgeriaAlgeriaAngolaAngolaAngolaBeninBe...
# Animal fats          AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Apples and products  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# ...                                                                ...
# ...

# %%
df[df["Item"]=="Wine"].value_counts()
# Out:
# Area Code  Area           Item Code  Item  Element Code  Element                              Unit         Y2014  Y2015  Y2016  Y2017  Y2018
# 4          Algeria        2655       Wine  645           Food supply quantity (kg/capita/yr)  kg           0.01   0.0    0.0    0.01   0.01     1
# 175        Guinea-Bissau  2655       Wine  5170          Residuals                            1000 tonnes  0.00   0.0    0.0    0.00   0.00     1
# 181        Zimbabwe       2655       Wine  5611          Import Quantity                      1000 tonnes  2.00   2.0    2.0    1.00   2.00     1
#                                            5511          Production                           1000 tonnes  2.00   2.0    2.0    2.00   2.00     1
#                                            5301          Domestic supply quantity             1000 tonnes  4.00   4.0    4.0    4.00   4.00     1
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %% [markdown]
# q6

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# #Q **13**

# %%
my_tuppy = (1,2,5,8)

# %%
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e0cfa6830280> in <cell line: 1>()
# ----> 1 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Q **14**

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
Percentage = (1589/60943)*100

# %%
Percentage
# Out:
# 2.6073544131401474

# %% [markdown]
# #Q **20**

# %%
df["Area"].nunique()
# Out:
# 49

# %% [markdown]
# #Q No 1

# %%
df.corr(df['Element Code'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-bc73f62b0b12> in <cell line: 1>()
# ----> 1 df.corr(df['Element Code'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %% [markdown]
# # Q no **2**

# %%
grouped_sum = df.groupby('Item').sum()

# %%
grouped_sum
# Out:
#                      Area Code  \
# Item
# Alcohol, Non-Food        38447
# Alcoholic Beverages      75016
# Animal Products          18060
# Animal fats              85279
# Apples and products      69280
# ...                        ...
# Vegetables, Other        77779
# Vegetal Products         18060
# Wheat and products       87073
# Wine                     66206
# Yams                     50798
#
#                                                                   Area  \
# Item
# Alcohol, Non-Food    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAngo...
# Alcoholic Beverages  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Animal Products      AlgeriaAlgeriaAlgeriaAngolaAngolaAngolaBeninBe...
# Animal fats          AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Apples and products  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# ...                                                                ...
# ...

# %% [markdown]
# #Q **No3**

# %%
grouped_sum = df.groupby('Element')

# %%
grouped_sum

# %% [markdown]
# #Q no7

# %%
df[(df["Area"]=="Madagascar") & (df["Element"]==" Protein supply quantity")].value_counts()
# Out:
# Series([], Name: count, dtype: int64)
